# %% [markdown]
# [Memorystore: Qwik Start](https://www.cloudskillsboost.google/focuses/31114?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23610656)

# %% [markdown]
# ![2023-04-30 18_13_38-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-30 18_17_13-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_33_40-Instances – Memorystore – qwiklabs-gcp-01-7cc… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_37_08-Create a Redis instance – Memorystore – qwiklabs-gcp-01-7cc… – Google Cloud cons.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_37_30-Create a Redis instance – Memorystore – qwiklabs-gcp-01-7cc… – Google Cloud cons.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_38_35-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/memorystore/docs/redis/networking#supported_and_unsupported_networks

# %% [markdown]
# ![2023-05-01 10_40_38-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# 10.229.116.99:6379

# %% [markdown]
# ![2023-05-01 10_55_52-Memorystore – qwiklabs-gcp-01-7cc… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_41_49-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_45_31-Instancje maszyn wirtualnych – Compute Engine – qwiklabs-gcp-01-7cc… – Google Cl.png](data:image/png;base64,...)

# %%
sudo apt-get install telnet

# %% [markdown]
# ![2023-05-01 10_46_30-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
telnet 10.229.116.99 6379

# %% [markdown]
# ![2023-05-01 10_47_40-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_48_54-https___ssh.cloud.google.com_v2_ssh_projects_qwiklabs-gcp-01-7cc2b0c01986_zones_.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_49_15-Magazyn pamięci_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
PING

# %% [markdown]
# ![2023-05-01 10_49_50-https___ssh.cloud.google.com_v2_ssh_projects_qwiklabs-gcp-01-7cc2b0c01986_zones_.png](data:image/png;base64,...)

# %%
SET HELLO WORLD

# %% [markdown]
# ![2023-05-01 10_50_45-https___ssh.cloud.google.com_v2_ssh_projects_qwiklabs-gcp-01-7cc2b0c01986_zones_.png](data:image/png;base64,...)

# %%
GET HELLO

# %% [markdown]
# ![2023-05-01 10_51_59-https___ssh.cloud.google.com_v2_ssh_projects_qwiklabs-gcp-01-7cc2b0c01986_zones_.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-01 10_54_25-test-vm – Compute Engine – qwiklabs-gcp-01-7cc… – Google Cloud Console.png](data:image/png;base64,...)
